# %% [markdown]
# ## IMPORTING MAIN LIBS

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## VISUALIZING AND MODIFYING DATA

# %%
df=pd.DataFrame(pd.read_csv('./data/911.csv') )
df.drop(['e'],axis=1,inplace=True) 
df
# Out:
#               lat        lng  \
# 0       40.297876 -75.581294
# 1       40.258061 -75.264680
# 2       40.121182 -75.351975
# 3       40.116153 -75.343513
# 4       40.251492 -75.603350
# ...           ...        ...
# 663517  40.157956 -75.348060
# 663518  40.136306 -75.428697
# 663519  40.013779 -75.300835
# 663520  40.121603 -75.351437
# 663521  40.015046 -75.299674
#
#                                                      desc      zip  \
# 0       REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1       BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2       HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3       AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4       CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
# ...                                                   ...      ...
# 663517  SUNSET AVE & WOODLAND AVE; EAST NORRITON; 2020...  19403.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 663522 entries, 0 to 663521
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   lat        663522 non-null  float64
#  1   lng        663522 non-null  float64
#  2   desc       663522 non-null  object
#  3   zip        583323 non-null  float64
#  4   title      663522 non-null  object
#  5   timeStamp  663522 non-null  object
#  6   twp        663229 non-null  object
#  7   addr       663522 non-null  object
# dtypes: float64(3), object(5)
# memory usage: 40.5+ MB

# %%
df.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:10:52        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:29:21  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK  2015-12-10 14:39:21         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY  2015-12-10 16:47:36         NORRISTOWN
# 4      NaN           EMS: DIZZINESS  2015-12-10 16:56:52   LOWER POTTSGROVE
#
#                          addr
# ...

# %% [markdown]
# ### top 5 zip codes and how many calls each have

# %%
df['zip'].value_counts().iloc[:5]
# Out:
# zip
# 19401.0    45606
# 19464.0    43910
# 19403.0    34888
# 19446.0    32270
# 19406.0    22464
# Name: count, dtype: int64

# %% [markdown]
# ### top 5 townships

# %%
df['twp'].value_counts().iloc[:5]
# Out:
# twp
# LOWER MERION    55490
# ABINGTON        39947
# NORRISTOWN      37633
# UPPER MERION    36010
# CHELTENHAM      30574
# Name: count, dtype: int64

# %% [markdown]
# ### top 5 situations by call

# %%
df['title'].value_counts().iloc[:5]
# Out:
# title
# Traffic: VEHICLE ACCIDENT -    148372
# Traffic: DISABLED VEHICLE -     47909
# Fire: FIRE ALARM                38336
# EMS: FALL VICTIM                34676
# EMS: RESPIRATORY EMERGENCY      34248
# Name: count, dtype: int64

# %% [markdown]
# ### adding new field reasons to summarize

# %%
df['reason']=df['title'].apply(lambda x: x.split(':')[0]) 
df
# Out:
#               lat        lng  \
# 0       40.297876 -75.581294
# 1       40.258061 -75.264680
# 2       40.121182 -75.351975
# 3       40.116153 -75.343513
# 4       40.251492 -75.603350
# ...           ...        ...
# 663517  40.157956 -75.348060
# 663518  40.136306 -75.428697
# 663519  40.013779 -75.300835
# 663520  40.121603 -75.351437
# 663521  40.015046 -75.299674
#
#                                                      desc      zip  \
# 0       REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1       BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2       HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3       AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4       CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
# ...                                                   ...      ...
# 663517  SUNSET AVE & WOODLAND AVE; EAST NORRITON; 2020...  19403.0
# ...

# %% [markdown]
# ### each reason and how many calls it got

# %%
df['reason'].value_counts()
# Out:
# reason
# EMS        332692
# Traffic    230208
# Fire       100622
# Name: count, dtype: int64

# %% [markdown]
# ### converting dates to datetime

# %%
df['timeStamp']=pd.to_datetime(df['timeStamp'])
df
# Out:
#               lat        lng  \
# 0       40.297876 -75.581294
# 1       40.258061 -75.264680
# 2       40.121182 -75.351975
# 3       40.116153 -75.343513
# 4       40.251492 -75.603350
# ...           ...        ...
# 663517  40.157956 -75.348060
# 663518  40.136306 -75.428697
# 663519  40.013779 -75.300835
# 663520  40.121603 -75.351437
# 663521  40.015046 -75.299674
#
#                                                      desc      zip  \
# 0       REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1       BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2       HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3       AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4       CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
# ...                                                   ...      ...
# 663517  SUNSET AVE & WOODLAND AVE; EAST NORRITON; 2020...  19403.0
# ...

# %%
df.dtypes
# Out:
# lat                 float64
# lng                 float64
# desc                 object
# zip                 float64
# title                object
# timeStamp    datetime64[ns]
# twp                  object
# addr                 object
# reason               object
# dtype: object

# %% [markdown]
# ### getting hour

# %%
df['hours']=df['timeStamp'].dt.hour 
df['hours']
# Out:
# 0         17
# 1         17
# 2         14
# 3         16
# 4         16
#           ..
# 663517    15
# 663518    15
# 663519    15
# 663520    15
# 663521    15
# Name: hours, Length: 663522, dtype: int32

# %% [markdown]
# ### agregating hours value

# %%
df['hours'].value_counts()
# Out:
# hours
# 17    44119
# 16    42797
# 15    42263
# 14    40346
# 12    40097
# 13    39797
# 11    38076
# 18    37322
# 10    36577
# 9     35477
# 8     33380
# 19    32442
# 20    28079
# 7     26971
# 21    24659
# 22    20313
# 6     17219
# 23    16892
# 0     13863
# 1     11751
# 5     11676
# 2     10653
# 3      9488
# 4      9265
# Name: count, dtype: int64

# %% [markdown]
# ### creating and agregating periodo column

# %%
conditions = [
    (df['hours'] >= 17) & (df['hours'] < 22),
    ((df['hours'] >= 22) | (df['hours'] < 6)),
    (df['hours'] >= 6) & (df['hours'] < 12),
    (df['hours'] >= 12) & (df['hours'] < 17)
]

# Define the corresponding values for each condition
choices = ['night', 'twilight', 'morning', 'afternoon/evening']

# Use numpy.select to assign values based on conditions
df['period'] = np.select(conditions, choices, default='Unknown')

df
# Out:
#               lat        lng  \
# 0       40.297876 -75.581294
# 1       40.258061 -75.264680
# 2       40.121182 -75.351975
# 3       40.116153 -75.343513
# 4       40.251492 -75.603350
# ...           ...        ...
# 663517  40.157956 -75.348060
# 663518  40.136306 -75.428697
# 663519  40.013779 -75.300835
# 663520  40.121603 -75.351437
# 663521  40.015046 -75.299674
#
#                                                      desc      zip  \
# 0       REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1       BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2       HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3       AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4       CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
# ...                                                   ...      ...
# 663517  SUNSET AVE & WOODLAND AVE; EAST NORRITON; 2020...  19403.0
# ...

# %%
df['period'].value_counts()
# Out:
# period
# afternoon/evening    205300
# morning              187700
# night                166621
# twilight             103901
# Name: count, dtype: int64

# %% [markdown]
# ### making a date column

# %%
df['date']=df['timeStamp'].apply(lambda x: x.date()) 
df
# Out:
#               lat        lng  \
# 0       40.297876 -75.581294
# 1       40.258061 -75.264680
# 2       40.121182 -75.351975
# 3       40.116153 -75.343513
# 4       40.251492 -75.603350
# ...           ...        ...
# 663517  40.157956 -75.348060
# 663518  40.136306 -75.428697
# 663519  40.013779 -75.300835
# 663520  40.121603 -75.351437
# 663521  40.015046 -75.299674
#
#                                                      desc      zip  \
# 0       REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1       BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2       HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3       AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4       CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
# ...                                                   ...      ...
# 663517  SUNSET AVE & WOODLAND AVE; EAST NORRITON; 2020...  19403.0
# ...

# %%
df['twp'].value_counts()
# Out:
# twp
# LOWER MERION       55490
# ABINGTON           39947
# NORRISTOWN         37633
# UPPER MERION       36010
# CHELTENHAM         30574
#                    ...
# EAST GREENVILLE     1316
# BRYN ATHYN          1254
# GREEN LANE           385
# PHILA COUNTY         267
# LEHIGH COUNTY        190
# Name: count, Length: 68, dtype: int64

# %% [markdown]
# ## PLOTTING GRAPHS

# %% [markdown]
# ### making simple countplot

# %%
sns.countplot(data=df,x='reason') 
plt.show()

# %% [markdown]
# ### making more complicated countplot

# %%
sns.countplot(data=df,x='reason') 
fig=sns.countplot(data=df,x='reason')  
fig.set_ybound=400000
for p in fig.patches: 
    fig.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points')
print(fig.get_ybound()) 
print(fig.get_ylim())  
fig.set_ylim(0.0,400000.0) 
fig.set_ylabel('Calls') 
fig.set_xlabel('Type') 
plt.tight_layout()
plt.show()
# Out:
# (0.0, 349326.6)
# (0.0, 349326.6)

# %% [markdown]
# ### making a completx countplot relating the type of the call with the hour

# %%
fig = sns.countplot(data=df, x='period', hue='reason')

for p in fig.patches:
    height_int = int(p.get_height())  # Convert the height to an integer
    fig.annotate(f'{height_int}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points', size="xx-small")

fig.set_ylim(0.0, 105092.3)
plt.legend(bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# ### counting nan in each column

# %%
df['has_nan'] = df['zip'].isna().astype(int) 
has_nan_counts = df['has_nan'].value_counts()
plt.figure(figsize=(8, 4))
ax=sns.barplot(x=has_nan_counts.index, y=has_nan_counts.values, palette='Set1') 
for p in ax.patches:
    height_int = int(p.get_height())  # Convert the height to an integer
    ax.annotate(f'{height_int}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points', size="medium")
ax.set_ylim(0.0,800000)
plt.title('Amount of "zip" columns with a NaN value')
plt.xlabel('')
plt.ylabel('Amt° of columns')
plt.xticks([0, 1], ['Does not have NaN value', 'Has a NaN value']) 
plt.show()
